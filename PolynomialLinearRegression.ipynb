# %% [markdown]
# ## Importing The Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing The Dataset

# %%
dataset = pd.read_csv("Position_Salaries.csv")
x = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# ## Training The Linear Regression Model on whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training The  Polynomial Linear Regression Model on whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
x_poly = poly_reg.fit_transform(x)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## visualizing  The Linear Regression Model  result

# %%
plt.scatter(x,y,color='red') 
plt.plot(x,lin_reg.predict(x),color='blue')
plt.title("Truth Or Bluff (Linear Regression")
plt.xlabel("Position Label")
plt.ylabel("salary") 
plt.show()

# %% [markdown]
# ## visualizing  The  Polynomial Linear Regression Model  result

# %%
plt.scatter(x,y,color='red') 
plt.plot(x,lin_reg_2.predict(poly_reg.fit_transform(x)),color='blue')
plt.title("Truth Or Bluff (polynomial Regression")
plt.xlabel("Position Label")
plt.ylabel("salary") 
plt.show()

# %% [markdown]
# ## visualizing  The  Polynomial Linear Regression Model  result (for higher resolution and smoother curve )

# %%
x_grid = np.arange(min(x),max(x),0.1)
x_grid = x_grid.reshape((len(x_grid),1))
plt.scatter(x,y,color='red') 
plt.plot(x_grid,lin_reg_2.predict(poly_reg.fit_transform(x_grid)),color='blue')
plt.title("Truth Or Bluff (polynomial Regression")  
plt.xlabel("Position Label")
plt.ylabel("salary") 
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7328\1994988483.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x),max(x),0.1)

# %% [markdown]
# ## Predicting The new result with Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting The new result with Linear Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265157])
